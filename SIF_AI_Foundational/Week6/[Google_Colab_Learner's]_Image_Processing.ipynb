# %% [markdown]
# #SIF Artificial Intelligence Founational - Image Processing 🌟🌏
#
# Image processing is an important field that has a wide range of applications in various industries, including healthcare, entertainment, manufacturing, and security. It involves the manipulation of digital images to extract information, enhance visual quality, or create new visual content.
#
# Learning about kernels and image processing is important for several reasons. First, it provides a fundamental understanding of how digital images are manipulated and processed. Understanding the concept of kernels and image processing algorithms enables individuals to develop their own image processing techniques and customize them to suit specific applications.

# %% [markdown]
# ![Screenshot 2023-03-27 at 2.40.01 AM.png](data:image/png;base64,...)

# %% [markdown]
# # Uploading and Processing Image

# %% [markdown]
# Upload Image

# %%
import cv2
from google.colab.patches import cv2_imshow

# Load the image
img = cv2.imread('#')

# Convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Display the grayscale image
cv2_imshow(gray)

# %% [markdown]
# # Algorithm behind kernel convolutions
#
# Recall Sentosa.io, where we created image effects with the webaapp.
#
#  https://setosa.io/ev/image-kernels/

# %% [markdown]
# ![Screenshot 2023-03-27 at 2.34.43 AM.png](data:image/png;base64,...)

# %% [markdown]
# Click 'Capture' to make photo using your webcam. To take the picture!

# %% [markdown]
# Read, resize and display the image.

# %%
import cv2
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload the image file
uploaded = files.upload()
for filename in uploaded.keys():
  img = cv2.imread(filename)

# Convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply edge detection
edges = cv2.Canny(gray, 100, 200)

# Apply Gaussian blur to the edges
blurred = cv2.GaussianBlur(

# Display the original image, grayscale, edges, and blurred images
cv2_imshow(img)
cv2_imshow(gray)
cv2_imshow(edges)
cv2_imshow(blurred)

# %% [markdown]
# #Apply a Gaussian blur filter to a grayscale image:
#
# This code first loads the image in grayscale mode using the cv2.imread() function from OpenCV. It then applies a Gaussian blur filter to the grayscale image using the cv2.GaussianBlur() function. The (5, 5) argument specifies the size of the kernel used for the blur, and the 0 argument specifies the standard deviation of the Gaussian distribution used for the blur. Finally, the original and blurred images are displayed side by side using the cv2.hconcat() function.
#
# Note that you can experiment with different kernel sizes and standard deviation values to achieve different levels of blur. Additionally, you can apply other types of blur filters, such as median or bilateral blur, to achieve different effects.

# %% [markdown]
# ![Screenshot 2023-03-27 at 2.42.49 AM.png](data:image/png;base64,...)

# %%
import cv2
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload the image file
uploaded = files.upload()
for filename in uploaded.keys():
  # Load the image in color mode
  img_color = cv2.imread(filename)

  # Convert the image to grayscale
  img_gray = cv2.cvtColor(img_color, cv2.COLOR_BGR2GRAY)

  # Apply Gaussian blur filter to the grayscale image
  img_blur = cv2.GaussianBlur(img_gray, (

  # Display the original and blurred images side by side
  cv2_imshow(cv2.hconcat([img_gray, img_blur]))

# %% [markdown]
# #Sobel edge detection to a grayscale image using a block of pixels as the kernel:
#
# This code first loads the image in grayscale mode using the cv2.imread() function from OpenCV. It then defines the Sobel kernel as a 3x3 block of pixels using a NumPy array. The cv2.filter2D() function is used to apply the Sobel filter to the grayscale image using the kernel. The -1 argument in the function call specifies that the output image should have the same depth as the input image. Finally, the original and Sobel-filtered images are displayed side by side using the cv2.hconcat() function.
#
# Note that you can experiment with different kernel sizes and values to achieve different levels of edge detection. Additionally, you can apply thresholding or other image processing techniques to further enhance the edges detected by the Sobel filter.

# %%
import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload the image file
uploaded = files.upload()
for filename in uploaded.keys():
  # Load the image in grayscale mode
  img_gray = cv2.imread(filename, cv2.IMREAD_GRAYSCALE)

  # Define the Sobel kernel as a block of pixels

  # Apply the Sobel filter to the grayscale image using the kernel
  img_sobel = cv2.filter2D(img_gray, -1, kernel)

  # Display the original and Sobel-filtered images side by side
  cv2_imshow(cv2.hconcat([img_gray, img_sobel]))

# %% [markdown]
# ![Screenshot 2023-03-27 at 2.45.34 AM.png](data:image/png;base64,...)

# %% [markdown]
# #Understanding RGB

# %%
import cv2
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload the image file
uploaded = files.upload()

# Loop through the uploaded files
for filename in uploaded.keys():
    # Read the image
    image = cv2.imread(filename)

    # Split the image into its three color channels
    blue, green, red = cv2.split(image)

    # Zero out the blue and green channels


    # Merge the red channel with the zeroed-out blue and green channels
    filtered_image = cv2.merge([blue, green, red])

    # Display the filtered image
    cv2_imshow(filtered_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %% [markdown]
# #Pause and Think 🤔
#
# In summary, understanding kernels and image processing is a crucial skill for anyone working with digital images, whether in research, industry, or creative fields. It provides a foundation for developing new image processing techniques and applications, as well as a deeper understanding of how images are manipulated and analyzed in various fields.

# %% [markdown]
# OpenCV’s deep learning face detector is based on the Single Shot Detector (SSD) framework with a ResNet base network. The network is defined and trained using the [Caffe Deep Learning framework](https://caffe.berkeleyvision.org/)

# %% [markdown]
# What are some applications of Facial recognition for social good? Please share more in your local context!

# %%
#Type here

# %% [markdown]
# What UN SDGs does it address?

# %%
#Type here
