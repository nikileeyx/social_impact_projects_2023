# %% [markdown]
# #Challenge 05: Dementia-friendly Communities in Singapore - Python Programming Code League 🏆
#
# Dementia friendliness is a crucial aspect of ensuring that individuals with dementia can lead a safe, dignified, and fulfilling life in society. In Singapore, dementia-friendly initiatives are aimed at creating a supportive and inclusive environment for people living with dementia. This includes training and education for caregivers and frontline staff, as well as adapting the physical environment to make it more accessible and user-friendly.
#
# The importance of dementia friendliness to citizens of Singapore cannot be overstated. With an ageing population, the number of people living with dementia is expected to rise significantly in the coming years. By promoting dementia-friendly practices, we can enable people with dementia to continue participating in society, reduce social isolation and stigma, and ensure that they receive the care and support they need to live with dignity and respect. Ultimately, creating a dementia-friendly society is not just about improving the lives of people with dementia but is a reflection of our values as a compassionate and inclusive community.

# %% [markdown]
# ![Screenshot 2023-03-26 at 8.20.07 AM.png](data:image/png;base64,...)

# %% [markdown]
# ##Example of Task
#
# Loops are an essential concept in programming that allow you to repeat a block of code multiple times. In Python, there are two types of loops: for loops and while loops.
#
# A for loop is used when you want to iterate over a sequence of values, such as a list, tuple, or string. The loop executes once for each element in the sequence, with a loop variable taking on the value of each element in turn.
#
# A while loop is used when you want to repeat a block of code while a certain condition is true. The loop continues to execute as long as the condition is true.
#
# Both types of loops use indentation to define the block of code that should be repeated. This block of code is often referred to as the loop body.
#
# Here's an example of a for loop in Python:
#
#
# ##**Now you can try the question!**

# %%
# Define a list of numbers
numbers = [1, 2, 3, 4, 5]

# Use a for loop to iterate through the list
for number in numbers:
    # Print each number
    print(number)

# %% [markdown]
# In this example, the for loop iterates through each element of the numbers list and prints it using the print() function.
#
# Here's an example of a while loop in Python:

# %%
# Define a counter variable
counter = 0

# Use a while loop to repeat a block of code while the counter is less than 5
while counter < 5:
    # Print the value of the counter
    print(counter)
    # Increment the counter by 1
    counter += 1

# %% [markdown]
# In this example, the while loop continues to execute as long as the counter variable is less than 5. The loop body prints the value of the counter using the print() function, and then increments the counter by 1 using the += operator.

# %% [markdown]
# ##Task 1: Create a Python Loop
#
# Objective: To create a quiz question related to the UN Sustainable Development Goals (SDGs) to test your classmates' knowledge.
#
# 1. Choose a goal to focus on and research the UN SDGs: Use the UN's website or other reputable sources to learn about the UN SDGs and their goals.
#
# 2. Choose one of the SDGs that you would like to create a quiz question about.
#
#
# 3. Create a question and multiple choice options. Write a multiple-choice question related to the SDG you have chosen. Provide at least three multiple choice options for the question.
#
# 4. Identify the correct answer for the question.
#
# 5. Write an explanation for the answer: Write a brief explanation for why the correct answer is the best option.

# %% [markdown]
# ##Explanation:
# The first line defines a list called numbers containing the values 1 to 5.
#
# The second line starts a for loop that will iterate through each element of the list.
#
# The third line defines a loop variable called number that will take on the value of each element of the list in turn.
#
# The fourth line is indented to indicate that it is part of the loop, and prints the value of number using the print() function.
#
# The loop will continue until all elements of the list have been processed.
# In this example, the output of the code will be:
#
#
#
# ```
# 1
# 2
# 3
# 4
# 5
# ```

# %%
# Define a list of numbers
numbers = [1, 2, 3, 4, 5]

# Use a for loop to iterate through the list
# The variable "number" will take on the value of each element of the list in turn
for number in numbers:
    # Print each number
    print(number)

# %% [markdown]
# #Using a "while" loop
#
# In this example, we define a list of numbers and initialize the loop counter i to zero.
#
# We then use a while loop to iterate through the list while the counter is less than the length of the list.
#
# Inside the loop, we print the current number at index i of the list and increment the loop counter.
#
# The loop continues until the counter i reaches the length of the list, at which point the loop terminates.

# %%
# Define a list of numbers
numbers = [1, 2, 3, 4, 5]

# Initialize the loop counter
i = 0

# Use a while loop to iterate through the list
while i < len(numbers):
    # Print the current number
    print(numbers[i])
    
    # Increment the loop counter
    i += 1

# %% [markdown]
# ##Task 2: Create a loop to dementia-friendly communiites in Singapore
#
# -------
#
#
# **Step 1:**
# Create a list called dementia_friendly_estates that contains the names of dementia-friendly estates in Singapore.
#
# **Step 2:**
# You can modify this list by adding or removing items as needed.
#
# **Step 3:**
# This loops through each item in the dementia_friendly_estates list and assigns it to a loop variable called estate. The loop body then prints the value of estate using the print() function.
#
# **Step 4:**
#  You should see each dementia-friendly estate in Singapore printed out on a separate line.
#
# ##**The blanks that you have to fill up are indicated with the "#" sign in the code cell below.**

# %%
# Define a list of dementia-friendly estates in Singapore
dementia_friendly_estates = []

# Use a for loop to iterate through the list and print each dementia-friendly estate
for estate in dementia_friendly_estates:
    print(estate)

# %% [markdown]
# #Dementia-friendliness in Singapore
#
# Dementia friendliness is a crucial aspect of ensuring that individuals with dementia can lead a safe, dignified, and fulfilling life in society. In Singapore, dementia-friendly initiatives are aimed at creating a supportive and inclusive environment for people living with dementia. This includes training and education for caregivers and frontline staff, as well as adapting the physical environment to make it more accessible and user-friendly.
#
#
# The importance of dementia friendliness to citizens of Singapore cannot be overstated. With an ageing population, the number of people living with dementia is expected to rise significantly in the coming years. By promoting dementia-friendly practices, we can enable people with dementia to continue participating in society, reduce social isolation and stigma, and ensure that they receive the care and support they need to live with dignity and respect. Ultimately, creating a dementia-friendly society is not just about improving the lives of people with dementia but is a reflection of our values as a compassionate and inclusive community.

# %% [markdown]
# ![Screenshot 2023-03-26 at 8.11.49 AM.png](data:image/png;base64,...)

# %% [markdown]
# ##Task 3: Create the above example using a "while" loop

# %% [markdown]
# #Reflections 🤔
#
# Which method did you find more useful?

# %% [markdown]
# What are some applications of "for" and "while" loops?

# %% [markdown]
# ##Congratuations! 🏆
# Good luck and happy programming! 👍
