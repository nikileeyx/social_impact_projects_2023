# %% [markdown]
# # Python Challenge 04: Maps Around the World Introduction
#
#
# Task: Maps Around the World Introduction
#
# This whole task is worth 100 points.
#
# ---
#
# Task 1: 10 points
#
# Task 2: 30 points
#
# Task 3: 60 points (with bonus 20 points)

# %% [markdown]
# #Task 1: Understanding Dictionaries in Python
#
# In Python, a dictionary is a collection of key-value pairs, where each key is associated with a value. Dictionaries are a built-in data type in Python and are commonly used to store and retrieve data in an efficient way.

# %% [markdown]
# ##Here's an example of how to create a dictionary in Python:
#
# In this example, we create a dictionary with three key-value pairs: "apple" is associated with the value 1, "banana" is associated with the value 2, and "orange" is associated with the value 3. We then print the dictionary, which outputs:

# %%
# Create a dictionary
my_dict = {"apple": 1, "banana": 2, "orange": 3}

# Print the dictionary
print(my_dict)

# %% [markdown]
# ##Accessing the Keys and values
#
# To access a value in a dictionary, you can use its corresponding key. In this example, we access the value associated with the key "apple", which outputs the value of "1"

# %%
# Access a value in the dictionary
print(my_dict["apple"])

# %% [markdown]
# ##Updating the Keys and values
#
# You can also add, update, or remove key-value pairs in a dictionary:

# %%
# Add a new key-value pair to the dictionary
my_dict["grape"] = 4

# Update the value associated with a key
my_dict["banana"] = 5

# Remove a key-value pair from the dictionary
del my_dict["orange"]

# Print the updated dictionary
print(my_dict)

# %% [markdown]
# In this example, we add a new key-value pair "grape": 4 to the dictionary, update the value associated with the key "banana" to 5, and remove the key-value pair associated with the key "orange". The updated dictionary is then printed:
#
#
#
# ```
# {'apple': 1, 'banana': 5, 'grape': 4}
# ```

# %% [markdown]
# ## 🌟 Task Description
#
# 1. Use the method of **updating the Keys and values** to change the values so that the value of "apple" is 10, "grape" is 20 and "banana" is 100.

# %%
#Write your code here

# %% [markdown]
# #Task 2: Increasing the length of the dictionary
#
# To add more key-value pairs to the my_dict dictionary, you can use the following syntax:

# %%
# Add a new key-value pair to the dictionary
my_dict["grape"] = 4

# Add multiple key-value pairs to the dictionary
my_dict.update({"kiwi": 5, "mango": 6})

# Print the updated dictionary
print(my_dict)

# %% [markdown]
# ## 🌟 Task Description
#
# 1. Use the lines of code above to change the value of the values in the dictionary to give the following output when you execute "print(fruit_dict)".
#
# ```
# {"apple": 10, "banana": 20, "orange": 30}
# ```
#
# 2. Use the functions "update" and reassigning values of each index to complete the task.
#
# Additional Pointer: You are not allowed to overwrite "fruit_dict".

# %%
#Start with this dictionary
fruit_dict = {"apple": 1, "banana": 2, "orange": 3}

#Write your code here
fruit_dict

# %% [markdown]
# # Task 3: Visualization of Data through Maps! 🌏
#
# In this example code, we have sample data consisting of three locations, each with a name, address, latitude, and longitude. We create a map using folium.Map(), specifying the center of the map and the zoom level.
#
# ---
#
#
# We then loop through the data, extracting the latitude, longitude, name, and address information for each location. We create a popup text string for each marker, and then add a marker to the map using folium.Marker().
#
#
# Finally, we display the map using m.

# %% [markdown]
# ## Let's try with one location in the world!
#
# We are using Central Park in New York! You can search "central park new york coordinates" on Google to find the latitude and longitude of the locations easily! 😊
#
#
# "data" is a list of length 1, it contains one dictionary.

# %%
# Import necessary libraries
import folium

# Sample data as a dictionary
data = [{
        "name": "Central Park",
        "address": "New York, NY",
        "latitude": 40.7829,
        "longitude": -73.9654
}]
 
# Create a map centered on a specific location
m = folium.Map(location=[39.8283, -98.5795], zoom_start=4)

# Loop through the data and add markers to the map
for location in data:
    lat = location['latitude']
    lon = location['longitude']
    name = location['name']
    address = location['address']
    popup_text = f"<b>{name}</b><br/>{address}"
    marker = folium.Marker(location=[lat, lon], popup=popup_text)
    marker.add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Let's try with another two locations!
#
# We are using Central Park in New York! You can search "central park new york coordinates" on Google to find the latitude and longitude of the locations easily! 😊
#
# "data" is a list of length 1, it contains one dictionary.
#
# ---
#
# **Pause and think! 🤔**
# 1. What is the length of the list "new_data"?
# 2. How many dictionar

# %%
# Import necessary libraries
import folium

# Sample data
data = [
    {
        "name": "Central Park",
        "address": "New York, NY",
        "latitude": 40.7829,
        "longitude": -73.9654
    }]

# Let's include two more locations to the dataset! We are creating a list to combine with the original list
new_locations = [{
        "name": "Golden Gate Bridge",
        "address": "San Francisco, CA",
        "latitude": 37.8199,
        "longitude": -122.4783
    },
    {
        "name": "Space Needle",
        "address": "Seattle, WA",
        "latitude": 47.6205,
        "longitude": -122.3493
    }]

#Combining the two lists of dictionaries, to form one list of dictionaries
new_data = data + new_locations

# Create a map centered on a specific location
m = folium.Map(location=[39.8283, -98.5795], zoom_start=4)

# Loop through the data and add markers to the map
for location in new_data:
    lat = location['latitude']
    lon = location['longitude']
    name = location['name']
    address = location['address']
    popup_text = f"<b>{name}</b><br/>{address}"
    marker = folium.Marker(location=[lat, lon], popup=popup_text)
    marker.add_to(m)

# Display the map
m

# %% [markdown]
# ## 🌟 Task Description
#
# You are a tour guide bringing your friends from New Zealand to Singapore for a day trip in Singapore around the theme "Heritage of Singapore", create a map of 3 locations for them on the map and display the map!
#
# Step 1: Create a new list called "attractions_in_Singapore"
#
# Step 2: Decide on 3 locations
#
# Step 3: Search for the coordinates of the locations that you are intending to include

# %%
# Import necessary libraries
import folium

# Write your code here

# %% [markdown]
# Write in more than 30 words, which locations will your bring your friend to and why!

# %%
# Write your response here

# %% [markdown]
# ##Congratuations! 🏆
# Once you have completed all the three questions, save a copy and turn in your solution to the Google Classroom! Let your trainer know when you have completed it.
#
# Good luck and happy programming! 👍
